# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import pandas as pd

# %% [markdown]
# # HW_00 - Generative AI writing analysis
#
# In this assignment, you will generate instructions on brushing your teeth. You can use [ChatGPT](https://chatgpt.com/)
#
# Some metrics to add to the generated instructions:
#
# - number of strokes per minute
# - total brushing time
# - time spent per tooth
# - number of teeth or total area to brush on teeth
# - deflection of brush bristles for proper cleaning
# - what else can you think of?

# %% [markdown]
# ## Prompt Input and Output
#
#
# #### My Prompt
# > Give me instructions on how to brush my teeth
#
# #### ChatGPT Output
# Sure, Jim! Here’s a quick step-by-step guide to brushing your teeth:
#
# What You’ll Need:
# A toothbrush (soft-bristled is recommended)
# Toothpaste (preferably fluoride-based)
# Water
# Floss (optional but recommended)
# Mouthwash (optional)
# Steps:
# Prepare Your Toothbrush
#
# Wet your toothbrush with a little water.
# Apply a pea-sized amount of toothpaste to the bristles.
# Start Brushing
#
# Hold your toothbrush at a 45-degree angle to your gums.
# Use gentle, circular motions to clean the front surfaces of your teeth (not hard scrubbing).
# Brush All Surfaces
#
# Front Surfaces: Clean the outer surfaces of all teeth.
# Back Surfaces: Flip your toothbrush to clean the inside surfaces of your teeth.
# Chewing Surfaces: Scrub the top of your molars where food particles collect.
# Focus on the Gums
#
# Gently brush along the gumline to remove plaque buildup, but don’t press too hard.
# Brush Your Tongue
#
# Run the bristles or a tongue scraper across your tongue to remove bacteria and freshen your breath.
# Rinse
#
# Spit out the toothpaste and rinse your mouth with water.
# Rinse your toothbrush thoroughly under running water.
# (Optional) Floss and Mouthwash
#
# Use floss to clean between your teeth. Slide it gently to avoid damaging gums.
# Swish with mouthwash for 30 seconds to kill bacteria and freshen breath.
# Tips:
# Brush for 2 minutes total (30 seconds per quadrant of your mouth).
# Brush twice a day (morning and night).
# Replace your toothbrush every 3-4 months or sooner if the bristles are frayed.
# Anything else you'd like help with? 😊

# %% [markdown]
# ## Revised document
#
# #### Revised Output
#
#
# 1. Wet your toothbrush with a water for 1 second. Apply a 0.25 grams  of toothpaste to the bristles. [GlaxoSmithKline Consumer Healthcare](https://pmc.ncbi.nlm.nih.gov/articles/PMC9375012/#:~:text='Pea%2Dsized'%20dispensing,are%20summarised%20in%20Table%202.)
#
# 2. Hold your toothbrush at a 45-degree angle to your gums. Use gentle, circular motions to clean the front surfaces of your teeth.
#
# 3. Clean the outer surfaces of all teeth for 30 Seconds.
#
# 4. Flip your toothbrush to clean the inside surfaces of your teeth for 30 Seconds.
#
# 5. Scrub the top of your molars where food particles collect for 30 Seconds.
#
# 6. Gently brush along the gumline to remove plaque buildup for 30 Seconds.
#
# 7. Brush the top side of your tounge in a circular motion for 15 seconds.
#
# 8. Spit out the toothpaste. Rinse your toothbrush under running water for 3 seconds. Do not rinse your mouth after brushing.

# %% [markdown]
# ## Document analysis
#
# - Make a list of all the improvements and changes you made to document
# - use the `tf_idf.cosineSimilarity` function to compare the AI version to your own
#
# Write a report on your intellectual property  in the 'revised document'.
# - How much can you claim as yours?
# - How many ideas came from AI?
# - How many ideas came from you?
# - Is this a _new_ document?
# - If this work was made by you and another person-not AI-would you need to credit this person as a coauthor?
# - What else can you discuss about this comparison and this process?
#
# _run the cell below to get your `tf_idf` functions ready to run_

# %%
! pip install tf-idf-cosimm==0.0.2

# %%
import tf_idf.core as tf_idf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import tf_idf.core as tf_idf
#       2 import nltk
#       3 nltk.download('punkt_tab')
#
# ModuleNotFoundError: No module named 'tf_idf'

# %%
AI = '''Sure, Jim! Here’s a quick step-by-step guide to brushing your teeth:

What You’ll Need: A toothbrush (soft-bristled is recommended) Toothpaste (preferably fluoride-based) Water Floss (optional but recommended) Mouthwash (optional) Steps: Prepare Your Toothbrush

Wet your toothbrush with a little water. Apply a pea-sized amount of toothpaste to the bristles. Start Brushing

Hold your toothbrush at a 45-degree angle to your gums. Use gentle, circular motions to clean the front surfaces of your teeth (not hard scrubbing). Brush All Surfaces

Front Surfaces: Clean the outer surfaces of all teeth. Back Surfaces: Flip your toothbrush to clean the inside surfaces of your teeth. Chewing Surfaces: Scrub the top of your molars where food particles collect. Focus on the Gums

Gently brush along the gumline to remove plaque buildup, but don’t press too hard. Brush Your Tongue

Run the bristles or a tongue scraper across your tongue to remove bacteria and freshen your breath. Rinse

Spit out the toothpaste and rinse your mouth with water. Rinse your toothbrush thoroughly under running water. (Optional) Floss and Mouthwash

Use floss to clean between your teeth. Slide it gently to avoid damaging gums. Swish with mouthwash for 30 seconds to kill bacteria and freshen breath. Tips: Brush for 2 minutes total (30 seconds per quadrant of your mouth). Brush twice a day (morning and night). Replace your toothbrush every 3-4 months or sooner if the bristles are frayed. Anything else you'd like help with? 😊'''
compare = tf_idf.preprocess_text(AI)

# %%
ME = '''Wet your toothbrush with a water for 1 second. Apply a 0.25 grams of toothpaste to the bristles. GlaxoSmithKline Consumer Healthcare

Hold your toothbrush at a 45-degree angle to your gums. Use gentle, circular motions to clean the front surfaces of your teeth.

Clean the outer surfaces of all teeth for 30 Seconds.

Flip your toothbrush to clean the inside surfaces of your teeth for 30 Seconds.

Scrub the top of your molars where food particles collect for 30 Seconds.

Gently brush along the gumline to remove plaque buildup for 30 Seconds.

Brush the top side of your tounge in a circular motion for 15 seconds.

Spit out the toothpaste. Rinse your toothbrush under running water for 3 seconds. Do not rinse your mouth after brushing.'''
compare = pd.concat([compare, tf_idf.preprocess_text(ME)],
                    ignore_index=True)
compare
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
tf_idf.cosineSimilarity(compare)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %% [markdown]
# I can claim the specific details when it comes to the amount and time recommendations. I added times based on how long I spend on these steps. I also looked up references to find the amount of toothpaste recomended for brushing. I can claim the step of not rinsing your mouth out after brushing.
#
# ChatGPT came up with all the steps for this process except for not rinsing out your mouth afterwards. The model came up with 7 steps along with an additional statement about what is needed.
#
# I deleted 2 of the steps ChatGPT came up with and also simplified the wording of the processes.
#
# This is a new document with a new style of writing and formatting. Some ideas are new while others are not. Much of the wording has been shortened.
#
# If this was originally writen by a real person I would credit them as a coauthor as many of these ideas did not come from myself. I did change the wording and formatting of every step along with add specifics. With a 0.62 cosine similarity score, I was able to alter the ChatGPT response by almost 40%.
